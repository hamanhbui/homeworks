# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import torch

def func_Psi(u):
    return torch.log(torch.cosh(torch.norm(u)))

def func_F(matrix_x, list_y):
    out = 0
    for y_k in list_y:
        out += func_Psi(y_k - torch.matmul(matrix_x, y_k))
    return out

def grad_F(matrix_x, list_y):
    matrix_x_clone = matrix_x.clone()
    matrix_x_clone = matrix_x_clone.detach().requires_grad_()
    out = func_F(matrix_x_clone, list_y)
    out.backward()
    return matrix_x_clone.grad

def line_search(alpha_bar, rho, c1, matrix_x, list_y):
    r_t = 0
    while True:
        alpha = alpha_bar * (rho ** r_t)
        grad =  grad_F(matrix_x, list_y)
        lhs = func_F(matrix_x - alpha * grad, list_y)
        rhs = func_F(matrix_x, list_y) - c1 * alpha * (torch.norm(grad) ** 2)
        if lhs <= rhs:
            break
        else:
            r_t += 1
    return alpha

def find_max_abs_of_X(matrix_x):
    out = torch.abs(matrix_x[0][0])
    for rows in matrix_x:
        for entry in rows:
            if torch.abs(entry) > out:
                out = torch.abs(entry)
    return out

def problem_3_5(list_y):
    matrix_x = torch.zeros(list_y.shape[1], list_y.shape[1], dtype = torch.float64)
    t, c1, alpha_bar, rho = 0, 0.01, 0.1, 0.9
    while True:
        alpha = line_search(alpha_bar, rho, c1, matrix_x, list_y)
        matrix_x_new = matrix_x - alpha * grad_F(matrix_x, list_y)
        if func_F(matrix_x, list_y) - func_F(matrix_x_new, list_y) <= 1e-6:
            break
        else:
            matrix_x = matrix_x_new
            t += 1
    print("The value of F at convergence: " + str(func_F(matrix_x_new, list_y).item()))
    print("The largest element of x in absolute value: "+ str(find_max_abs_of_X(matrix_x_new).item()))
    print("The number of required iterations: " + str(t))

# %%
if __name__ == "__main__":
    list_y = pd.read_csv('homework2_data/project2_Y.csv')
    list_y = list_y.drop(['Unnamed: 0'], axis=1).to_numpy()
    list_y = torch.tensor(list_y, dtype = torch.float64)
    
    problem_3_5(list_y)
# Out:
# The value of F at convergence: 0.0001609264200027296
# The largest element of x in absolute value: 0.7562430492024295
# The number of required iterations: 344

# %%
def get_q_t(list_l, t, m):
    j = t % m
    q_t = list_l[j+1]
    return q_t

def get_xi_l(l, dims):
    x_i_l = torch.zeros(dims, dims, dtype = torch.float64)
    x_i_l[l[0], l[1]] = 1
    x_i_l[l[1], l[0]] = 1
    return x_i_l

def partial_F(q_t, matrix_x, list_y):
    out = 0
    i, j = q_t[0], q_t[1]
    for y_k in list_y:
        z_k = y_k - torch.matmul(matrix_x, y_k)
        out += (torch.tanh(torch.norm(z_k))/torch.norm(z_k)) * (z_k[i] * y_k[j] + z_k[j] * y_k[i])
    return -out

def problem_3_6(list_y, list_l):
    matrix_x = torch.zeros(list_y.shape[1], list_y.shape[1], dtype = torch.float64)
    t, c1, alpha_bar, rho = 0, 0.01, 1, 0.9
    list_x = []
    m = len(list_l) - 1
    while True:
        q_t = get_q_t(list_l, t, m)
        alpha = line_search(alpha_bar, rho, c1, matrix_x, list_y)
        partial = partial_F(q_t, matrix_x, list_y)
        if torch.abs(partial) >= 1e-8:
            matrix_x = matrix_x - alpha * partial * get_xi_l(q_t, list_y.shape[1])
        list_x.append(matrix_x)
        if t % 100 == 0:
          print("The value of F at step " + str(t) + ": " + str(func_F(matrix_x, list_y).item()))
        if t >= m and func_F(list_x[t - m], list_y) - func_F(list_x[t], list_y) <= 1e-6:
            break
        else:
            t += 1
    print("The value of F at convergence: " + str(func_F(matrix_x, list_y).item()))
    print("The largest element of x in absolute value: "+ str(find_max_abs_of_X(matrix_x).item()))
    print("The number of required iterations: " + str(t))

# %%
if __name__ == "__main__":
    list_l = pd.read_csv('homework2_data/project2_C.csv')
    list_l = list_l.drop(['Unnamed: 0'], axis=1).to_numpy()
    list_l = torch.tensor(list_l)
    
    problem_3_6(list_y, list_l)
# Out:
# The value of F at step 0: 43.620559521709644
# The value of F at step 100: 41.301439847013675
# The value of F at step 200: 38.0635355100751
# The value of F at step 300: 34.42411062419935
# The value of F at step 400: 32.29601053384496
# The value of F at step 500: 29.418292797610444
# The value of F at step 600: 25.813478185126307
# The value of F at step 700: 23.7629304253249
# The value of F at step 800: 23.221621709965877
# The value of F at step 900: 22.413552160657854
# The value of F at step 1000: 21.623327655136695
# The value of F at step 1100: 21.045642492030506
# The value of F at step 1200: 20.290504543072583
# The value of F at step 1300: 19.658159772679713
# The value of F at step 1400: 19.396162961724045
# The value of F at step 1500: 19.122656051888242
# The value of F at step 1600: 18.77007558377296
# The value of F at step 1700: 18.516365588350503
# The value of F at step 1800: 18.260942138036594
# The value of F at step 1900: 17.930389521341045
# The value of F at step 2000: 17.75305258820033
# The value of F at step 2100: 17.58097396423212
# The value of F at step 2200: 17.421494283871006
# The value of F at step 2300: 17.262189678011104
# The value of F at step 2400: 17.134509908681924
# The value of F at step 2500: 16.961555202844888
# The value of F at step 2600: 16.81582247404745
# The value of F at step 2700: 16.743954760594214
# The value of F at step 2800: 16.633046212324082
# The value of F at step 2900: 16.51465923865554
# The value of F at step 3000: 16.442372877913257
# The value of F at step 3100: 16.335306759739368
# The value of F at step 3200: 16.239630595529796
# The value of F at step 3300: 16.17509022851798
# The value of F at step 3400: 16.114586745126548
# The value of F at step 3500: 16.033481678685387
# The value of F at step 3600: 15.977527482853121
# The value of F at step 3700: 15.924334405273488
# The value of F at step 3800: 15.840935033621527
# The value of F at step 3900: 15.795360443013655
# The value of F at step 4000: 15.747665322402945
# The value of F at step 4100: 15.705537328708298
# The value of F at step 4200: 15.658274344584493
# The value of F at step 4300: 15.624610416261584
# The value of F at step 4400: 15.566711061186991
# The value of F at step 4500: 15.527913301302979
# The value of F at step 4600: 15.504599490599091
# The value of F at step 4700: 15.46873016171594
# The value of F at step 4800: 15.430240255586803
# The value of F at step 4900: 15.408000328591308
# The value of F at step 5000: 15.369378710106474
# The value of F at step 5100: 15.337452905883543
# The value of F at step 5200: 15.31434325487919
# The value of F at step 5300: 15.29040859256234
# The value of F at step 5400: 15.263080987013216
# The value of F at step 5500: 15.244743492940705
# The value of F at step 5600: 15.224816387402116
# The value of F at step 5700: 15.192297592973727
# The value of F at step 5800: 15.174834208019487
# The value of F at step 5900: 15.155306621572535
# The value of F at step 6000: 15.139118313052515
# The value of F at step 6100: 15.122010157263029
# The value of F at step 6200: 15.109686311761003
# The value of F at step 6300: 15.082965653959306
# The value of F at step 6400: 15.068854882913643
# The value of F at step 6500: 15.05932779445432
# The value of F at step 6600: 15.043789972244586
# The value of F at step 6700: 15.028281755375469
# The value of F at step 6800: 15.018394135738212
# The value of F at step 6900: 15.002390922964379
# The value of F at step 7000: 14.988320726395036
# The value of F at step 7100: 14.978288103158594
# The value of F at step 7200: 14.966408621094603
# The value of F at step 7300: 14.954491143415648
# The value of F at step 7400: 14.948155556376312
# The value of F at step 7500: 14.939104727940167
# The value of F at step 7600: 14.923748667904258
# The value of F at step 7700: 14.915899803753566
# The value of F at step 7800: 14.905727544131567
# The value of F at step 7900: 14.89875568809991
# The value of F at step 8000: 14.891670463409712
# The value of F at step 8100: 14.886243230025531
# The value of F at step 8200: 14.872961976082616
# The value of F at step 8300: 14.866447008588443
# The value of F at step 8400: 14.862104361088074
# The value of F at step 8500: 14.854018639616758
# The value of F at step 8600: 14.84683135876118
# The value of F at step 8700: 14.842321958949775
# The value of F at step 8800: 14.834490400702974
# The value of F at step 8900: 14.827455292506759
# The value of F at step 9000: 14.822636409915779
# The value of F at step 9100: 14.8159987924429
# The value of F at step 9200: 14.810378557490964
# The value of F at step 9300: 14.807626156523552
# The value of F at step 9400: 14.803035738056261
# The value of F at step 9500: 14.79511792156777
# The value of F at step 9600: 14.791268417524671
# The value of F at step 9700: 14.785556124856253
# The value of F at step 9800: 14.781982173881788
# The value of F at step 9900: 14.7787453098497
# The value of F at step 10000: 14.776119906849411
# The value of F at step 10100: 14.76902570150768
# The value of F at step 10200: 14.765747678721356
# The value of F at step 10300: 14.763590304086675
# The value of F at step 10400: 14.758898233172996
# The value of F at step 10500: 14.755263228674234
# The value of F at step 10600: 14.752994506852792
# The value of F at step 10700: 14.748935034217284
# The value of F at step 10800: 14.745083488491487
# The value of F at step 10900: 14.742645431884617
# The value of F at step 11000: 14.738607794269916
# The value of F at step 11100: 14.735730041077726
# The value of F at step 11200: 14.734325300375998
# The value of F at step 11300: 14.731934339722589
# The value of F at step 11400: 14.727592588697146
# The value of F at step 11500: 14.725598153023528
# The value of F at step 11600: 14.722154013934807
# The value of F at step 11700: 14.720135073407922
# The value of F at step 11800: 14.718535892931403
# The value of F at step 11900: 14.717185221328076
# The value of F at step 12000: 14.7132220183445
# The value of F at step 12100: 14.711422598936215
# The value of F at step 12200: 14.710360105196434
# The value of F at step 12300: 14.707374824495389
# The value of F at step 12400: 14.705403186433257
# The value of F at step 12500: 14.704166224697687
# The value of F at step 12600: 14.702016388311158
# The value of F at step 12700: 14.699803385466126
# The value of F at step 12800: 14.698501920570473
# The value of F at step 12900: 14.695897911096415
# The value of F at step 13000: 14.694318724008681
# The value of F at step 13100: 14.693589918792874
# The value of F at step 13200: 14.692290811376308
# The value of F at step 13300: 14.68977005689829
# The value of F at step 13400: 14.68868451510036
# The value of F at step 13500: 14.686462021020516
# The value of F at step 13600: 14.685245956327446
# The value of F at step 13700: 14.684430399864079
# The value of F at step 13800: 14.68371321020323
# The value of F at step 13900: 14.681436487242829
# The value of F at step 14000: 14.680415733039274
# The value of F at step 14100: 14.679833256165779
# The value of F at step 14200: 14.67785279876337
# The value of F at step 14300: 14.676718012559416
# The value of F at step 14400: 14.676049125547353
# The value of F at step 14500: 14.674839758050238
# The value of F at step 14600: 14.673515597441362
# The value of F at step 14700: 14.672791765956383
# The value of F at step 14800: 14.671040755890639
# The value of F at step 14900: 14.670128025879245
# The value of F at step 15000: 14.669732228620962
# The value of F at step 15100: 14.669004038319136
# The value of F at step 15200: 14.667494393756547
# The value of F at step 15300: 14.666895603868515
# The value of F at step 15400: 14.665401657297444
# The value of F at step 15500: 14.664632350997124
# The value of F at step 15600: 14.664192707885107
# The value of F at step 15700: 14.663788072433308
# The value of F at step 15800: 14.662451897270985
# The value of F at step 15900: 14.66185755865564
# The value of F at step 16000: 14.661521435043344
# The value of F at step 16100: 14.66014386216984
# The value of F at step 16200: 14.659468904147419
# The value of F at step 16300: 14.659100704844871
# The value of F at step 16400: 14.658403151242426
# The value of F at step 16500: 14.657591238139432
# The value of F at step 16600: 14.657170959044134
# The value of F at step 16700: 14.655954198410377
# The value of F at step 16800: 14.655405612501776
# The value of F at step 16900: 14.65518051446382
# The value of F at step 17000: 14.654733761916981
# The value of F at step 17100: 14.653841013233823
# The value of F at step 17200: 14.653498512703417
# The value of F at step 17300: 14.652426723145147
# The value of F at step 17400: 14.651957557760593
# The value of F at step 17500: 14.651709041427038
# The value of F at step 17600: 14.651480755116754
# The value of F at step 17700: 14.650653769941794
# The value of F at step 17800: 14.650320042304193
# The value of F at step 17900: 14.6501054616661
# The value of F at step 18000: 14.649136350015548
# The value of F at step 18100: 14.64872489228459
# The value of F at step 18200: 14.648516482973005
# The value of F at step 18300: 14.648062596569805
# The value of F at step 18400: 14.647598524086073
# The value of F at step 18500: 14.647344626725898
# The value of F at step 18600: 14.6464798888698
# The value of F at step 18700: 14.646139604963821
# The value of F at step 18800: 14.64600721938977
# The value of F at step 18900: 14.645724666552368
# The value of F at step 19000: 14.64519104893034
# The value of F at step 19100: 14.644988905385382
# The value of F at step 19200: 14.6442085165537
# The value of F at step 19300: 14.643915549258931
# The value of F at step 19400: 14.64376561704138
# The value of F at step 19500: 14.643635277284789
# The value of F at step 19600: 14.64313307854809
# The value of F at step 19700: 14.64292848519756
# The value of F at step 19800: 14.642790143278743
# The value of F at step 19900: 14.642093362458558
# The value of F at step 20000: 14.641832557100205
# The value of F at step 20100: 14.641712530382973
# The value of F at step 20200: 14.641436780399653
# The value of F at step 20300: 14.641131535421419
# The value of F at step 20400: 14.6409857170329
# The value of F at step 20500: 14.640361542251613
# The value of F at step 20600: 14.640147118851125
# The value of F at step 20700: 14.640064347898074
# The value of F at step 20800: 14.639894683408313
# The value of F at step 20900: 14.639560376699482
# The value of F at step 21000: 14.639437915201766
# The value of F at step 21100: 14.638873571054885
# The value of F at step 21200: 14.638676877541105
# The value of F at step 21300: 14.63858883001556
# The value of F at step 21400: 14.638508014998639
# The value of F at step 21500: 14.638199551314486
# The value of F at step 21600: 14.638068507537442
# The value of F at step 21700: 14.637980106852318
# The value of F at step 21800: 14.637469182602924
# The value of F at step 21900: 14.637304508166924
# The value of F at step 22000: 14.637233279604205
# The value of F at step 22100: 14.637062024640564
# The value of F at step 22200: 14.636869880537215
# The value of F at step 22300: 14.636773285768598
# The value of F at step 22400: 14.636319327166895
# The value of F at step 22500: 14.636179183528538
# The value of F at step 22600: 14.636129275180586
# The value of F at step 22700: 14.63602519535154
# The value of F at step 22800: 14.635813762550248
# The value of F at step 22900: 14.635736990899758
# The value of F at step 23000: 14.6353226045708
# The value of F at step 23100: 14.635186340693771
# The value of F at step 23200: 14.635137726062181
# The value of F at step 23300: 14.635088160152469
# The value of F at step 23400: 14.634894125065749
# The value of F at step 23500: 14.634811810085903
# The value of F at step 23600: 14.634751389762798
# The value of F at step 23700: 14.634374534555532
# The value of F at step 23800: 14.634269188407844
# The value of F at step 23900: 14.634225981772648
# The value of F at step 24000: 14.63410729678396
# The value of F at step 24100: 14.63399604310051
# The value of F at step 24200: 14.633931052791036
# The value of F at step 24300: 14.633597602707102
# The value of F at step 24400: 14.633506278335489
# The value of F at step 24500: 14.633474551073782
# The value of F at step 24600: 14.633409462467084
# The value of F at step 24700: 14.633274077900811
# The value of F at step 24800: 14.63322505157114
# The value of F at step 24900: 14.632920503092707
# The value of F at step 25000: 14.632827374049258
# The value of F at step 25100: 14.632796938336522
# The value of F at step 25200: 14.632766010411217
# The value of F at step 25300: 14.63264332754474
# The value of F at step 25400: 14.632589128545208
# The value of F at step 25500: 14.63254796075237
# The value of F at step 25600: 14.632266951587736
# The value of F at step 25700: 14.63220049101089
# The value of F at step 25800: 14.632174079389902
# The value of F at step 25900: 14.632099375207995
# The value of F at step 26000: 14.632026990847265
# The value of F at step 26100: 14.631982255576677
# The value of F at step 26200: 14.63173604275588
# The value of F at step 26300: 14.631675307621153
# The value of F at step 26400: 14.63165480711041
# The value of F at step 26500: 14.631614122287061
# The value of F at step 26600: 14.631526768463907
# The value of F at step 26700: 14.631494850049476
# The value of F at step 26800: 14.631269750748435
# The value of F at step 26900: 14.631204527036472
# The value of F at step 27000: 14.631186317134441
# The value of F at step 27100: 14.631166433977006
# The value of F at step 27200: 14.631081545757066
# The value of F at step 27300: 14.631052879693835
# The value of F at step 27400: 14.631023575922237
# The value of F at step 27500: 14.63081441256032
# The value of F at step 27600: 14.630771682384504
# The value of F at step 27700: 14.630755142344512
# The value of F at step 27800: 14.630707997209958
# The value of F at step 27900: 14.630660179225416
# The value of F at step 28000: 14.630628808889721
# The value of F at step 28100: 14.630446535366728
# The value of F at step 28200: 14.630406105391808
# The value of F at step 28300: 14.630392579708474
# The value of F at step 28400: 14.630366473490595
# The value of F at step 28500: 14.630309753940521
# The value of F at step 28600: 14.63028779493731
# The value of F at step 28700: 14.63012060440125
# The value of F at step 28800: 14.630076634738051
# The value of F at step 28900: 14.630064734346593
# The value of F at step 29000: 14.630051687649644
# The value of F at step 29100: 14.629996930067657
# The value of F at step 29200: 14.62997818054803
# The value of F at step 29300: 14.629956988947747
# The value of F at step 29400: 14.629800150558681
# The value of F at step 29500: 14.629772970844435
# The value of F at step 29600: 14.6297629467198
# The value of F at step 29700: 14.629725927250652
# The value of F at step 29800: 14.629701069931444
# The value of F at step 29900: 14.629678779745962
# The value of F at step 30000: 14.629543502188238
# The value of F at step 30100: 14.629516289486563
# The value of F at step 30200: 14.629507234816487
# The value of F at step 30300: 14.6294904067064
# The value of F at step 30400: 14.629453344858948
# The value of F at step 30500: 14.629438335944688
# The value of F at step 30600: 14.629314114870766
# The value of F at step 30700: 14.629283749764916
# The value of F at step 30800: 14.62927576248249
# The value of F at step 30900: 14.629267282702484
# The value of F at step 31000: 14.629231543617493
# The value of F at step 31100: 14.62921919029428
# The value of F at step 31200: 14.629203706665155
# The value of F at step 31300: 14.629087384498389
# The value of F at step 31400: 14.629069204277284
# The value of F at step 31500: 14.629062689998529
# The value of F at step 31600: 14.629038822526518
# The value of F at step 31700: 14.62902206601529
# The value of F at step 31800: 14.629006019461515
# The value of F at step 31900: 14.628905314690433
# The value of F at step 32000: 14.628887076693443
# The value of F at step 32100: 14.628880987888461
# The value of F at step 32200: 14.628869938239665
# The value of F at step 32300: 14.628845405023942
# The value of F at step 32400: 14.628835344909353
# The value of F at step 32500: 14.628742794615432
# The value of F at step 32600: 14.628721616756449
# The value of F at step 32700: 14.62871624913667
# The value of F at step 32800: 14.628710296829938
# The value of F at step 32900: 14.628687095893838
# The value of F at step 33000: 14.628678910336065
# The value of F at step 33100: 14.628667520092913
# The value of F at step 33200: 14.628581144964071
# The value of F at step 33300: 14.628568873885659
# The value of F at step 33400: 14.628564600741134
# The value of F at step 33500: 14.628549114712369
# The value of F at step 33600: 14.628537778392436
# The value of F at step 33700: 14.628526076663057
# The value of F at step 33800: 14.628451167961337
# The value of F at step 33900: 14.628438761672088
# The value of F at step 34000: 14.628434590850995
# The value of F at step 34100: 14.628427264367076
# The value of F at step 34200: 14.62841107654313
# The value of F at step 34300: 14.628404120586396
# The value of F at step 34400: 14.628335179190564
# The value of F at step 34500: 14.628320278489184
# The value of F at step 34600: 14.628316610746925
# The value of F at step 34700: 14.628312558495672
# The value of F at step 34800: 14.628297297701577
# The value of F at step 34900: 14.628291775049917
# The value of F at step 35000: 14.62828335101917
# The value of F at step 35100: 14.628219174573422
# The value of F at step 35200: 14.628210810155407
# The value of F at step 35300: 14.628207986790017
# The value of F at step 35400: 14.628197864641649
# The value of F at step 35500: 14.628190152385864
# The value of F at step 35600: 14.6281815652572
# The value of F at step 35700: 14.628125795328588
# The value of F at step 35800: 14.628117200896925
# The value of F at step 35900: 14.628114448964237
# The value of F at step 36000: 14.628109542540571
# The value of F at step 36100: 14.628098786882767
# The value of F at step 36200: 14.628093966839105
# The value of F at step 36300: 14.628042536702717
# The value of F at step 36400: 14.628031997284305
# The value of F at step 36500: 14.628029473882847
# The value of F at step 36600: 14.628026340833658
# The value of F at step 36700: 14.628016597703486
# The value of F at step 36800: 14.628012815175527
# The value of F at step 36900: 14.628006570570484
# The value of F at step 37000: 14.627958814673685
# The value of F at step 37100: 14.627953138078261
# The value of F at step 37200: 14.627951235660445
# The value of F at step 37300: 14.627944589340203
# The value of F at step 37400: 14.6279392576121
# The value of F at step 37500: 14.627932941629197
# The value of F at step 37600: 14.627891416698446
# The value of F at step 37700: 14.627885505103997
# The value of F at step 37800: 14.627883597035902
# The value of F at step 37900: 14.627880291980045
# The value of F at step 38000: 14.627873020113562
# The value of F at step 38100: 14.627869741887967
# The value of F at step 38200: 14.627830651120911
# The value of F at step 38300: 14.627823862648889
# The value of F at step 38400: 14.62782211544884
# The value of F at step 38500: 14.627819987687312
# The value of F at step 38600: 14.627813479319634
# The value of F at step 38700: 14.627810844670002
# The value of F at step 38800: 14.62780621588839
# The value of F at step 38900: 14.627770684950343
# The value of F at step 39000: 14.627766797264247
# The value of F at step 39100: 14.62776547245792
# The value of F at step 39200: 14.627761109609791
# The value of F at step 39300: 14.627757226152722
# The value of F at step 39400: 14.627752749061573
# The value of F at step 39500: 14.627721799946832
# The value of F at step 39600: 14.627717675436818
# The value of F at step 39700: 14.62771638597425
# The value of F at step 39800: 14.627714141089509
# The value of F at step 39900: 14.627709229336785
# The value of F at step 40000: 14.62770695496964
# The value of F at step 40100: 14.62767775227849
# The value of F at step 40200: 14.62767294193388
# The value of F at step 40300: 14.627671722774094
# The value of F at step 40400: 14.627670245105993
# The value of F at step 40500: 14.627665893821394
# The value of F at step 40600: 14.627664050390358
# The value of F at step 40700: 14.6276606052066
# The value of F at step 40800: 14.62763414881863
# The value of F at step 40900: 14.627631427068314
# The value of F at step 41000: 14.627630564660999
# The value of F at step 41100: 14.627627666743242
# The value of F at step 41200: 14.627624984736153
# The value of F at step 41300: 14.627621636663102
# The value of F at step 41400: 14.627598546723572
# The value of F at step 41500: 14.627595687960177
# The value of F at step 41600: 14.62759480203257
# The value of F at step 41700: 14.62759326104076
# The value of F at step 41800: 14.627589947974604
# The value of F at step 41900: 14.627586825338089
# The value of F at step 42000: 14.627566519019389
# The value of F at step 42100: 14.627563094130867
# The value of F at step 42200: 14.627562225254826
# The value of F at step 42300: 14.627561208048602
# The value of F at step 42400: 14.627558016081121
# The value of F at step 42500: 14.62755685277125
# The value of F at step 42600: 14.627554412134597
# The value of F at step 42700: 14.627534654782854
# The value of F at step 42800: 14.627532824979003
# The value of F at step 42900: 14.627532160933551
# The value of F at step 43000: 14.62753029528865
# The value of F at step 43100: 14.627528431147837
# The value of F at step 43200: 14.627525922141889
# The value of F at step 43300: 14.627508706502603
# The value of F at step 43400: 14.627506717921474
# The value of F at step 43500: 14.627506092625998
# The value of F at step 43600: 14.627505026063838
# The value of F at step 43700: 14.627502770509103
# The value of F at step 43800: 14.62750029957009
# The value of F at step 43900: 14.627485240855494
# The value of F at step 44000: 14.627482883020557
# The value of F at step 44100: 14.62748226999199
# The value of F at step 44200: 14.62748155846427
# The value of F at step 44300: 14.627479401347493
# The value of F at step 44400: 14.627478574006242
# The value of F at step 44500: 14.627476733821348
# The value of F at step 44600: 14.627462017139585
# The value of F at step 44700: 14.627460749747604
# The value of F at step 44800: 14.627460265436634
# The value of F at step 44900: 14.627458832927582
# The value of F at step 45000: 14.627457726850386
# The value of F at step 45100: 14.62745585083191
# The value of F at step 45200: 14.627443008940592
# The value of F at step 45300: 14.627441624437685
# The value of F at step 45400: 14.627441179591987
# The value of F at step 45500: 14.627440359737045
# The value of F at step 45600: 14.627438900952495
# The value of F at step 45700: 14.627437000646495
# The value of F at step 45800: 14.627425786643846
# The value of F at step 45900: 14.627424147444811
# The value of F at step 46000: 14.6274237128949
# The value of F at step 46100: 14.62742321166939
# The value of F at step 46200: 14.627421748084094
# The value of F at step 46300: 14.627421157607472
# The value of F at step 46400: 14.627419768277212
# The value of F at step 46500: 14.627408800550807
# The value of F at step 46600: 14.627407921497461
# The value of F at step 46700: 14.627407580479339
# The value of F at step 46800: 14.627406615378272
# The value of F at step 46900: 14.627405836168275
# The value of F at step 47000: 14.627404424783228
# The value of F at step 47100: 14.62739484563759
# The value of F at step 47200: 14.627393876559594
# The value of F at step 47300: 14.627393558825073
# The value of F at step 47400: 14.62739298857006
# The value of F at step 47500: 14.627391988661975
# The value of F at step 47600: 14.627390539972948
# The value of F at step 47700: 14.627382203721588
# The value of F at step 47800: 14.627381032373993
# The value of F at step 47900: 14.627380723239538
# The value of F at step 48000: 14.627380358386578
# The value of F at step 48100: 14.6273793711396
# The value of F at step 48200: 14.62737893879587
# The value of F at step 48300: 14.62737789787395
# The value of F at step 48400: 14.627369716330913
# The value of F at step 48500: 14.627369110367844
# The value of F at step 48600: 14.627368869300692
# The value of F at step 48700: 14.627368209279302
# The value of F at step 48800: 14.627367656304218
# The value of F at step 48900: 14.627366600940993
# The value of F at step 49000: 14.62735945480881
# The value of F at step 49100: 14.627358774491803
# The value of F at step 49200: 14.627358546360579
# The value of F at step 49300: 14.627358147607898
# The value of F at step 49400: 14.627357459342614
# The value of F at step 49500: 14.627356374755452
# The value of F at step 49600: 14.627350155250761
# The value of F at step 49700: 14.627349316043288
# The value of F at step 49800: 14.62734909507072
# The value of F at step 49900: 14.627348836227
# The value of F at step 50000: 14.627348160561025
# The value of F at step 50100: 14.627347825901722
# The value of F at step 50200: 14.627347060314444
# The value of F at step 50300: 14.627340962969537
# The value of F at step 50400: 14.627340538911414
# The value of F at step 50500: 14.627340367394261
# The value of F at step 50600: 14.627339918239235
# The value of F at step 50700: 14.627339525909111
# The value of F at step 50800: 14.6273387248252
# The value of F at step 50900: 14.627333397720582
# The value of F at step 51000: 14.627332918537338
# The value of F at step 51100: 14.627332754377713
# The value of F at step 51200: 14.627332444379459
# The value of F at step 51300: 14.627331997742427
# The value of F at step 51400: 14.627331183304857
# The value of F at step 51500: 14.627326537727832
# The value of F at step 51600: 14.627325941249932
# The value of F at step 51700: 14.627325783018264
# The value of F at step 51800: 14.627325596189817
# The value of F at step 51900: 14.627325134000685
# The value of F at step 52000: 14.627324889536828
# The value of F at step 52100: 14.627324311107056
# The value of F at step 52200: 14.627319766082717
# The value of F at step 52300: 14.62731946814483
# The value of F at step 52400: 14.627319345819078
# The value of F at step 52500: 14.62731903851201
# The value of F at step 52600: 14.627318758924934
# The value of F at step 52700: 14.627318154600939
# The value of F at step 52800: 14.627314179153402
# The value of F at step 52900: 14.62731384073848
# The value of F at step 53000: 14.627313719070674
# The value of F at step 53100: 14.627313504126034
# The value of F at step 53200: 14.627313192795535
# The value of F at step 53300: 14.6273125822058
# The value of F at step 53400: 14.627309085992584
# The value of F at step 53500: 14.627308685493395
# The value of F at step 53600: 14.627308572028998
# The value of F at step 53700: 14.627308434879403
# The value of F at step 53800: 14.627308119431172
# The value of F at step 53900: 14.62730794250751
# The value of F at step 54000: 14.627307503103973
# The value of F at step 54100: 14.627304114510387
# The value of F at step 54200: 14.627303904427679
# The value of F at step 54300: 14.627303815133892
# The value of F at step 54400: 14.627303604481725
# The value of F at step 54500: 14.627303405948826
# The value of F at step 54600: 14.627302949608744
# The value of F at step 54700: 14.62729998150176
# The value of F at step 54800: 14.627299741891864
# The value of F at step 54900: 14.627299653095386
# The value of F at step 55000: 14.62729949938235
# The value of F at step 55100: 14.627299285380733
# The value of F at step 55200: 14.627298826557025
# The value of F at step 55300: 14.627296213552643
# The value of F at step 55400: 14.627295928419848
# The value of F at step 55500: 14.627295846960312
# The value of F at step 55600: 14.627295748245766
# The value of F at step 55700: 14.627295530199225
# The value of F at step 55800: 14.627295401808777
# The value of F at step 55900: 14.627295067921866
# The value of F at step 56000: 14.627292536379082
# The value of F at step 56100: 14.627292392516372
# The value of F at step 56200: 14.627292328426606
# The value of F at step 56300: 14.627292180381309
# The value of F at step 56400: 14.627292040631323
# The value of F at step 56500: 14.6272916960749
# The value of F at step 56600: 14.627289480478412
# The value of F at step 56700: 14.627289309865988
# The value of F at step 56800: 14.62728923909081
# The value of F at step 56900: 14.627289136460709
# The value of F at step 57000: 14.627288986425823
# The value of F at step 57100: 14.62728864176012
# The value of F at step 57200: 14.627286662914896
# The value of F at step 57300: 14.627286485350874
# The value of F at step 57400: 14.627286426635102
# The value of F at step 57500: 14.62728635532978
# The value of F at step 57600: 14.62728620407449
# The value of F at step 57700: 14.627286110291664
# The value of F at step 57800: 14.627285856985548
# The value of F at step 57900: 14.627283967096135
# The value of F at step 58000: 14.627283867050414
# The value of F at step 58100: 14.627283820609922
# The value of F at step 58200: 14.627283718105822
# The value of F at step 58300: 14.627283617290692
# The value of F at step 58400: 14.627283357419245
# The value of F at step 58500: 14.627281702924524
# The value of F at step 58600: 14.62728158035614
# The value of F at step 58700: 14.62728153028284
# The value of F at step 58800: 14.627281457498016
# The value of F at step 58900: 14.62728135179815
# The value of F at step 59000: 14.62728109246604
# The value of F at step 59100: 14.627279609691517
# The value of F at step 59200: 14.627279487221962
# The value of F at step 59300: 14.627279444838127
# The value of F at step 59400: 14.627279393050431
# The value of F at step 59500: 14.627279287901297
# The value of F at step 59600: 14.6272792196121
# The value of F at step 59700: 14.627279027199092
# The value of F at step 59800: 14.627277616998368
# The value of F at step 59900: 14.627277546354733
# The value of F at step 60000: 14.627277512393587
# The value of F at step 60100: 14.627277441350781
# The value of F at step 60200: 14.627277368647096
# The value of F at step 60300: 14.627277172324318
# The value of F at step 60400: 14.627275937066608
# The value of F at step 60500: 14.627275849552309
# The value of F at step 60600: 14.627275812944498
# The value of F at step 60700: 14.627275761140135
# The value of F at step 60800: 14.62727568638072
# The value of F at step 60900: 14.627275490681134
# The value of F at step 61000: 14.627274384230672
# The value of F at step 61100: 14.627274295813944
# The value of F at step 61200: 14.627274265100771
# The value of F at step 61300: 14.627274227522491
# The value of F at step 61400: 14.627274153926717
# The value of F at step 61500: 14.627274103956617
# The value of F at step 61600: 14.627273951498642
# The value of F at step 61700: 14.627272903430732
# The value of F at step 61800: 14.627272855674136
# The value of F at step 61900: 14.627272831119173
# The value of F at step 62000: 14.627272780525605
# The value of F at step 62100: 14.627272728807176
# The value of F at step 62200: 14.62727258041792
# The value of F at step 62300: 14.627271658084894
# The value of F at step 62400: 14.627271594940613
# The value of F at step 62500: 14.627271568529416
# The value of F at step 62600: 14.627271531640783
# The value of F at step 62700: 14.627271478547017
# The value of F at step 62800: 14.627271331224161
# The value of F at step 62900: 14.627270503094998
# The value of F at step 63000: 14.627270441130738
# The value of F at step 63100: 14.62727041877725
# The value of F at step 63200: 14.627270391502861
# The value of F at step 63300: 14.627270339928083
# The value of F at step 63400: 14.627270300338418
# The value of F at step 63500: 14.627269727957103
# The value of F at step 63600: 14.627269405547173
# The value of F at step 63700: 14.62726937161917
# The value of F at step 63800: 14.627269353606655
# The value of F at step 63900: 14.627269318218403
# The value of F at step 64000: 14.627269280713028
# The value of F at step 64100: 14.627269168642739
# The value of F at convergence: 14.627268743106319
# The largest element of x in absolute value: 0.7640178922678903
# The number of required iterations: 64133
